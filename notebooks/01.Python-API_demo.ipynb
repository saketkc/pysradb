# %% [markdown]
# <a href="https://colab.research.google.com/github/saketkc/pysradb/blob/master/notebooks/01_Python_API_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/saketkc/pysradb
# Out:
# Collecting git+https://github.com/saketkc/pysradb
#   Cloning https://github.com/saketkc/pysradb to /tmp/pip-req-build-ddydd894
#   Running command git clone -q https://github.com/saketkc/pysradb /tmp/pip-req-build-ddydd894
# Requirement already satisfied (use --upgrade to upgrade): pysradb==0.10.4.dev0 from git+https://github.com/saketkc/pysradb in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: pandas==1.0.1 in /usr/local/lib/python3.6/dist-packages (from pysradb==0.10.4.dev0) (1.0.1)
# Requirement already satisfied: requests==2.23.0 in /usr/local/lib/python3.6/dist-packages (from pysradb==0.10.4.dev0) (2.23.0)
# Requirement already satisfied: tqdm==4.43.0 in /usr/local/lib/python3.6/dist-packages (from pysradb==0.10.4.dev0) (4.43.0)
# Requirement already satisfied: xmltodict==0.12.0 in /usr/local/lib/python3.6/dist-packages (from pysradb==0.10.4.dev0) (0.12.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas==1.0.1->pysradb==0.10.4.dev0) (1.18.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas==1.0.1->pysradb==0.10.4.dev0) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas==1.0.1->pysradb==0.10.4.dev0) (2018.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pysradb==0.10.4.dev0) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pysradb==0.10.4.dev0) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pysradb==0.10.4.dev0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests==2.23.0->pysradb==0.10.4.dev0) (3.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas==1.0.1->pysradb==0.10.4.dev0) (1.12.0)
# Building wheels for collected packages: pysradb
#   Building wheel for pysradb (setup.py) ... done
#   Created wheel for pysradb: filename=pysradb-0.10.4.dev0-cp36-none-any.whl size=148757 sha256=bffe2b71bc34b1544dc90371da383096ba6c26f51c78c528dd22ff69608b4c6f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-76tledhn/wheels/f1/4f/ae/d1dfa9578767bcdbf0e89ea7c07ed2f10fc221761e0a155fc7
# Successfully built pysradb

# %%
# !pysradb --version
# Out:
# pysradb 0.10.4-dev0

# %%
from pysradb.sraweb import SRAweb
# Out:
# /usr/local/lib/python3.6/dist-packages/pysradb/sradb.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
db = SRAweb()

# %% [markdown]
# # Get metadata of one project

# %%
df = db.sra_metadata('SRP016501')
df
# Out:
#     study_accession experiment_accession  ... run_total_spots run_total_bases
# 0         SRP016501            SRX196397  ...        37423394      2993871520
# 1         SRP016501            SRX196396  ...        24401708      1756922976
# 2         SRP016501            SRX196395  ...        25606436      1792450520
# 3         SRP016501            SRX196394  ...        26604280      1862299600
# 4         SRP016501            SRX196393  ...        18978066      1366420752
# ..              ...                  ...  ...             ...             ...
# 129       SRP016501            SRX196268  ...       116292478     11629247800
# 130       SRP016501            SRX196267  ...       119274786     11927478600
# 131       SRP016501            SRX196266  ...        35175982      2532670704
# 132       SRP016501            SRX196265  ...       101816491     10181649100
# 133       SRP016501            SRX196264  ...        87264604      8726460400
#
# [134 rows x 17 columns]

# %% [markdown]
# # Get detailed metadata

# %%
df = db.sra_metadata('SRP016501', detailed=True)
df
# Out:
#     study_accession  ...                                    ena_fastq_ftp_2
# 0         SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 1         SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 2         SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 3         SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 4         SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# ..              ...  ...                                                ...
# 129       SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 130       SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 131       SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 132       SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
# 133       SRP016501  ...  era-fasp@fasp.sra.ebi.ac.uk:vol1/fastq/SRR594/...
#
# [134 rows x 27 columns]

# %% [markdown]
# # Get metadata of multiple projects

# %%
df = db.sra_metadata(['SRP016501', 'SRP098789'])
df
# Out:
#     study_accession experiment_accession  ... run_total_spots run_total_bases
# 0         SRP098789           SRX2536428  ...        69422931      3540569481
# 1         SRP098789           SRX2536427  ...        58065134      2961321834
# 2         SRP098789           SRX2536426  ...        63720205      3249730455
# 3         SRP098789           SRX2536425  ...        66363585      3384542835
# 4         SRP098789           SRX2536424  ...        40062613      2043193263
# ..              ...                  ...  ...             ...             ...
# 155       SRP016501            SRX196268  ...       116292478     11629247800
# 156       SRP016501            SRX196267  ...       119274786     11927478600
# 157       SRP016501            SRX196266  ...        35175982      2532670704
# 158       SRP016501            SRX196265  ...       101816491     10181649100
# 159       SRP016501            SRX196264  ...        87264604      8726460400
#
# [160 rows x 17 columns]

# %% [markdown]
# # SRX to GSM

# %%
df = db.srx_to_gsm('SRX1254413')
df
# Out:
#   experiment_accession experiment_alias
# 0           SRX1254413       GSM1887643
