# %% [markdown]
# <a href="https://colab.research.google.com/github/saketkc/pysradb/blob/master/01.Python-API_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/saketkc/pysradb
# Out:
# ...
#   Cloning https://github.com/saketkc/pysradb to /tmp/pip-req-build-dssj_jsv
#   Running command git clone -q https://github.com/saketkc/pysradb /tmp/pip-req-build-dssj_jsv
# ...
#   Created wheel for pysradb: filename=pysradb-0.10.3.dev0-cp36-none-any.whl size=147408 sha256=98781bcd026102532499686ecb514363479279a91bd452203dd16296d1064bf2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1npic0xt/wheels/f1/4f/ae/d1dfa9578767bcdbf0e89ea7c07ed2f10fc221761e0a155fc7
# Successfully built pysradb

# %%
# !pysradb --version
# Out:
# pysradb 0.10.3-dev0

# %%
from pysradb.sraweb import SRAweb

# %%
db = SRAweb()

# %%
df = db.sra_metadata('SRP016501')
df
# Out:
#     study_accession experiment_accession  ... run_total_spots run_total_bases
# 0         SRP016501            SRX196397  ...        37423394      2993871520
# 1         SRP016501            SRX196396  ...        24401708      1756922976
# 2         SRP016501            SRX196395  ...        25606436      1792450520
# 3         SRP016501            SRX196394  ...        26604280      1862299600
# 4         SRP016501            SRX196393  ...        18978066      1366420752
# ..              ...                  ...  ...             ...             ...
# 129       SRP016501            SRX196268  ...       116292478     11629247800
# 130       SRP016501            SRX196267  ...       119274786     11927478600
# 131       SRP016501            SRX196266  ...        35175982      2532670704
# 132       SRP016501            SRX196265  ...       101816491     10181649100
# 133       SRP016501            SRX196264  ...        87264604      8726460400
#
# [134 rows x 17 columns]

# %% [markdown]
# # Get detailed metadata

# %%
df = db.sra_metadata('SRP016501', detailed=True)
df
# Out:
#     study_accession experiment_accession  ...           tissue  strain
# 0         SRP016501            SRX196397  ...           testes     N/A
# 1         SRP016501            SRX196396  ...           spleen     N/A
# 2         SRP016501            SRX196395  ...  skeletal muscle     N/A
# 3         SRP016501            SRX196394  ...             lung     N/A
# 4         SRP016501            SRX196393  ...            liver     N/A
# ..              ...                  ...  ...              ...     ...
# 129       SRP016501            SRX196268  ...            liver  DBA/2J
# 130       SRP016501            SRX196267  ...           kidney  DBA/2J
# 131       SRP016501            SRX196266  ...            heart  DBA/2J
# 132       SRP016501            SRX196265  ...            colon  DBA/2J
# 133       SRP016501            SRX196264  ...            brain  DBA/2J
#
# [134 rows x 23 columns]

# %% [markdown]
# # SRX to GSM

# %%
df = db.srx_to_gsm('SRX1254413')
df
# Out:
#   experiment_accession experiment_alias
# 0           SRX1254413       GSM1887643
